# %%
import pandas as pd
import time
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from tqdm import tqdm

# Start timing the whole process
start_time = time.time()

# Load the training data
train_data_path = r"C:\Users\Mohammad Hijjawi\Desktop\Data Science Project Code\BERT - Introduction\Training\Large\large_training_data_set_bert_introduction_embeddings.csv"
train_data = pd.read_csv(train_data_path)

# Shuffle the dataset
train_data = train_data.sample(frac=1, random_state=42).reset_index(drop=True)

# Prepare the inputs and labels for training
X_train = train_data.drop(columns=['title', 'introduction', 'categories', 'infobox_type'])
y_train = train_data['infobox_type']

# Use the best parameters found
best_params = {'C': 4.594506741382034, 'coef0': 0.09541011649041131, 'degree': 4, 'gamma': 'scale', 'kernel': 'rbf'}

# Initialize the SVM classifier with the best parameters
best_svm_classifier = SVC(
    C=best_params['C'],
    coef0=best_params['coef0'],
    degree=best_params['degree'],
    gamma=best_params['gamma'],
    kernel=best_params['kernel'],
    random_state=42
)

# Fit the classifier to the training data
best_svm_classifier.fit(X_train, y_train)

# Notify training completion
training_end_time = time.time()
print(f"Training completed in {training_end_time - start_time:.2f} seconds")
print(f"Using parameters: {best_params}")

# Load the testing data
test_data_path = r"C:\Users\Mohammad Hijjawi\Desktop\Data Science Project Code\BERT - Introduction\Testing\testing_data_set_for_bert_introduction.csv"
test_data = pd.read_csv(test_data_path)

# Drop the 'categories_text' column from the test dataset if it exists and prepare the inputs and labels for testing
if 'categories_text' in test_data.columns:
    test_data = test_data.drop(columns=['categories_text'])
X_test = test_data.drop(columns=['title', 'introduction', 'categories', 'infobox_type'])
y_test = test_data['infobox_type']

# Process the test data in chunks
chunk_size = 100
total_chunks = len(test_data) // chunk_size + (1 if len(test_data) % chunk_size != 0 else 0)

results_df_list = []
for i in tqdm(range(total_chunks), desc="Processing test data"):
    start_idx = i * chunk_size
    end_idx = min((i + 1) * chunk_size, len(test_data))
    X_test_chunk = X_test.iloc[start_idx:end_idx]
    y_test_chunk = y_test.iloc[start_idx:end_idx]
    titles_test_chunk = test_data['title'].iloc[start_idx:end_idx]

    # Predict the test data chunk
    y_pred_chunk = best_svm_classifier.predict(X_test_chunk)

    # Create a DataFrame with the chunk results
    chunk_results_df = pd.DataFrame({
        'Title': titles_test_chunk,
        'Predicted Label': y_pred_chunk,
        'True Label': y_test_chunk
    })
    results_df_list.append(chunk_results_df)

# Concatenate all results into a single DataFrame
results_df = pd.concat(results_df_list, ignore_index=True)

# Analyze misclassifications and identify the top 5 most misclassified labels
misclassified = results_df[results_df['Predicted Label'] != results_df['True Label']]
misclass_counts = misclassified['True Label'].value_counts()
top_misclassified = misclass_counts.head(5)
print("Top 5 Most Misclassified Labels:")
print(top_misclassified)

# End timing the whole process
end_time = time.time()
print(f"Testing completed in {end_time - training_end_time:.2f} seconds")

# Generate and print the classification report
report = classification_report(results_df['True Label'], results_df['Predicted Label'], output_dict=True)
print(classification_report(results_df['True Label'], results_df['Predicted Label']))

# Print total execution time
print(f"Total execution time: {end_time - start_time:.2f} seconds")

# Specify the path where you want to save the results
results_csv_path = r"C:\Users\Mohammad Hijjawi\Desktop\Data Science Project Code\BERT - Introduction\Training\Large\SVM\prediction_results.csv"

# Save results to CSV
results_df.to_csv(results_csv_path, index=False)
print(f"Results saved to {results_csv_path}")
# Out:
# Training completed in 784.66 seconds
# Using parameters: {'C': 4.594506741382034, 'coef0': 0.09541011649041131, 'degree': 4, 'gamma': 'scale', 'kernel': 'rbf'}
# Processing test data: 100%|██████████████████████████████████████████████████████████| 298/298 [41:18<00:00,  8.32s/it]
# Top 5 Most Misclassified Labels:
# True Label
# infobox person                      67
# infobox event                       52
# infobox gridiron football person    44
# infobox building                    44
# infobox company                     43
# Name: count, dtype: int64
# Testing completed in 2482.84 seconds
#                                                precision    recall  f1-score   support
#
#                              infobox academic       0.59      0.58      0.59       100
#                         infobox afl biography       0.99      1.00      1.00       100
#                        infobox aircraft begin       0.95      0.99      0.97       100
#                   infobox aircraft occurrence       0.99      0.95      0.97       100
#                               infobox airline       0.96      0.98      0.97       100
#                               infobox airport       0.96      0.94      0.95       100
#                                 infobox album       0.96      0.99      0.98       100
#                               infobox anatomy       0.98      0.98      0.98       100
#                          infobox ancient site       0.79      0.95      0.86       100
#                              infobox animanga       0.97      0.99      0.98       100
#                             infobox architect       0.96      0.97      0.97       100
#                                infobox artist       0.82      0.85      0.83       100
#                    infobox artist discography       0.97      0.93      0.95       100
#                               infobox artwork       0.96      0.93      0.94       100
#               infobox athletics championships       0.89      0.94      0.91       100
#                      infobox australian place       0.91      0.95      0.93       100
#                            infobox automobile       0.94      0.93      0.93       100
#                                 infobox award       0.90      0.83      0.86       100
#                      infobox badminton player       0.97      1.00      0.99       100
#                    infobox baseball biography       0.96      0.98      0.97       100
#                  infobox baseball team season       0.96      0.99      0.98       100
#                  infobox basketball biography       0.99      0.96      0.97       100
#                       infobox basketball club       0.91      0.99      0.95       100
#              infobox basketball league season       0.90      0.96      0.93       100
#                        infobox beauty pageant       0.98      0.99      0.99       100
#                   infobox bilateral relations       0.98      0.99      0.99       100
#                         infobox body of water       0.88      0.79      0.83       100
#                                  infobox book       0.77      0.85      0.81       100
#                           infobox book series       0.85      0.82      0.84       100
#                                 infobox boxer       0.91      0.97      0.94       100
#                                 infobox brand       0.81      0.82      0.82       100
#                                infobox bridge       0.91      0.94      0.93       100
#                              infobox building       0.60      0.56      0.58       100
#                           infobox bus transit       0.92      0.98      0.95       100
#             infobox canada electoral district       0.99      1.00      1.00       100
#                              infobox cemetery       0.96      0.97      0.97       100
#                         infobox cfl biography       0.69      0.60      0.64       100
#                             infobox character       0.87      0.86      0.86       100
#                          infobox chess player       1.00      1.00      1.00       100
#                               infobox chinese       0.65      0.84      0.73       100
#                infobox christian denomination       0.87      0.91      0.89       100
#                      infobox christian leader       0.88      0.92      0.90       100
#                                infobox church       0.76      0.87      0.81       100
#                        infobox civil conflict       0.74      0.81      0.78       100
#                       infobox civilian attack       0.65      0.81      0.72       100
#                         infobox college coach       0.93      0.87      0.90       100
#               infobox college football player       0.82      0.95      0.88       100
#            infobox college sports team season       0.97      1.00      0.99       100
#                              infobox comedian       0.88      0.88      0.88       100
#                      infobox comic book title       0.96      0.97      0.97       100
#                      infobox comics character       0.98      0.94      0.96       100
#                        infobox comics creator       0.93      0.95      0.94       100
#                               infobox company       0.72      0.57      0.64       100
#                               infobox concert       0.99      0.96      0.97       100
#                          infobox constituency       0.99      0.97      0.98       100
#                               infobox country       0.65      0.77      0.71       100
#                      infobox country at games       0.98      0.96      0.97       100
#                            infobox court case       0.96      0.91      0.93       100
#                        infobox cricket ground       0.98      0.99      0.99       100
#                          infobox cricket team       0.98      0.97      0.97       100
#                          infobox cricket tour       0.96      0.99      0.98       100
#                             infobox cricketer       0.99      0.99      0.99       100
#                              infobox criminal       0.80      0.81      0.81       100
#                              infobox cultivar       1.00      0.97      0.98       100
#                                infobox curler       0.99      0.99      0.99       100
#                          infobox cycling race       0.99      1.00      1.00       100
#                   infobox cycling race report       0.99      0.99      0.99       100
#                               infobox cyclist       0.99      0.97      0.98       100
#                                   infobox dam       0.92      0.93      0.93       100
#                          infobox darts player       1.00      1.00      1.00       100
#                                 infobox deity       0.90      0.95      0.92       100
#                            infobox diagnostic       0.93      0.94      0.94       100
#                               infobox diocese       0.94      0.94      0.94       100
#                                  infobox drug       0.99      0.96      0.97       100
#                            infobox earthquake       0.99      0.97      0.98       100
#                             infobox economist       0.90      0.88      0.89       100
#                              infobox election       0.95      0.94      0.94       100
#                                infobox enzyme       0.98      0.91      0.94       100
#                          infobox ethnic group       0.97      0.88      0.92       100
#                                 infobox event       0.68      0.48      0.56       100
#                          infobox field hockey       0.96      0.99      0.98       100
#                   infobox field hockey player       0.96      0.99      0.98       100
#                         infobox figure skater       0.98      0.98      0.98       100
#            infobox figure skating competition       0.99      0.99      0.99       100
#                                  infobox film       0.93      0.93      0.93       100
#                           infobox film awards       0.94      0.93      0.93       100
#                       infobox fivb tournament       0.96      0.97      0.97       100
#                                  infobox flag       0.97      0.95      0.96       100
#                                  infobox food       0.97      0.94      0.95       100
#                    infobox football biography       0.99      0.97      0.98       100
#                         infobox football club       0.94      0.95      0.95       100
#                  infobox football club season       0.93      0.95      0.94       100
#               infobox football country season       0.97      0.95      0.96       100
#                       infobox football league       0.87      0.90      0.88       100
#                infobox football league season       0.86      0.79      0.82       100
#                        infobox football match       0.85      0.91      0.88       100
#                   infobox football tournament       0.84      0.84      0.84       100
#            infobox football tournament season       0.84      0.80      0.82       100
#                    infobox former subdivision       0.85      0.83      0.84       100
#                        infobox french commune       0.97      0.99      0.98       100
#                    infobox french subdivision       1.00      1.00      1.00       100
#                              infobox gaa club       0.98      1.00      0.99       100
#    infobox gaelic athletic association player       1.00      1.00      1.00       100
#                                infobox galaxy       1.00      1.00      1.00       100
#                                  infobox game       0.93      0.96      0.95       100
#                                 infobox games       0.90      0.85      0.88       100
#                       infobox german location       0.97      0.99      0.98       100
#                            infobox given name       0.89      0.85      0.87       100
#                               infobox glacier       0.95      0.98      0.97       100
#                           infobox golf season       1.00      1.00      1.00       100
#                       infobox golf tournament       0.99      0.97      0.98       100
#                                infobox golfer       0.98      0.97      0.97       100
#                     infobox government agency       0.78      0.77      0.77       100
#                    infobox government cabinet       0.96      0.94      0.95       100
#                infobox grand prix race report       1.00      0.99      0.99       100
#                           infobox greek dimos       0.94      0.99      0.97       100
#              infobox gridiron football person       0.58      0.56      0.57       100
#                               infobox gymnast       0.99      1.00      1.00       100
#                    infobox handball biography       1.00      1.00      1.00       100
#                          infobox hiking trail       0.94      0.95      0.95       100
#                          infobox hindu temple       0.82      0.96      0.88       100
#                         infobox historic site       0.74      0.59      0.66       100
#                               infobox holiday       0.87      0.87      0.87       100
#                            infobox horseraces       1.00      0.99      0.99       100
#               infobox horseracing personality       0.98      0.99      0.99       100
#                              infobox hospital       0.93      0.95      0.94       100
#                                 infobox hotel       0.93      0.94      0.94       100
#                  infobox hurling championship       0.97      0.99      0.98       100
#                     infobox ice hockey player       0.99      0.97      0.98       100
#                infobox ice hockey team season       0.98      1.00      0.99       100
#                   infobox indian constituency       0.99      1.00      1.00       100
#            infobox individual golf tournament       0.97      1.00      0.99       100
#         infobox individual snooker tournament       1.00      1.00      1.00       100
#                 infobox information appliance       0.96      0.86      0.91       100
#    infobox international football competition       0.87      0.86      0.86       100
#                               infobox islands       0.79      0.90      0.84       100
#                        infobox italian comune       0.92      0.97      0.95       100
#                               infobox journal       0.97      0.97      0.97       100
#                                 infobox judge       0.98      0.96      0.97       100
#                                infobox judoka       0.95      0.99      0.97       100
#                           infobox korean name       0.74      0.88      0.80       100
#                              infobox landform       0.65      0.71      0.68       100
#                              infobox language       0.90      0.88      0.89       100
#                       infobox language family       0.92      0.90      0.91       100
#                infobox law enforcement agency       0.93      0.88      0.90       100
#                           infobox legislation       0.87      0.88      0.88       100
#                  infobox legislative district       1.00      0.99      0.99       100
#                  infobox legislative election       0.76      0.94      0.84       100
#                           infobox legislature       0.88      0.84      0.86       100
#                               infobox library       0.88      0.84      0.86       100
#                            infobox lighthouse       0.98      0.93      0.95       100
#                            infobox locomotive       0.95      0.97      0.96       100
#                          infobox lunar crater       1.00      1.00      1.00       100
#                              infobox magazine       0.78      0.85      0.81       100
#           infobox malaysia electoral district       1.00      1.00      1.00       100
#                        infobox martial artist       0.91      0.87      0.89       100
#                     infobox medical condition       0.95      0.95      0.95       100
#                        infobox medical person       0.80      0.84      0.82       100
#                        infobox military award       0.92      0.98      0.95       100
#                     infobox military conflict       0.79      0.85      0.82       100
#                       infobox military person       0.94      0.87      0.90       100
#                    infobox military structure       0.83      0.80      0.82       100
#                         infobox military unit       0.95      0.90      0.92       100
#                                  infobox mine       0.97      0.96      0.96       100
#                               infobox mineral       1.00      1.00      1.00       100
#                 infobox minor league baseball       0.98      0.99      0.99       100
#                             infobox mma event       0.99      1.00      1.00       100
#                          infobox mobile phone       0.92      0.97      0.95       100
#                                 infobox model       0.80      0.89      0.84       100
#                             infobox monastery       0.87      0.90      0.89       100
#                              infobox monument       0.65      0.72      0.69       100
#                      infobox motorcycle rider       0.98      0.95      0.96       100
#                              infobox mountain       0.93      0.86      0.90       100
#                         infobox mountain pass       0.94      0.90      0.92       100
#                                infobox museum       0.91      0.80      0.85       100
#                           infobox music genre       0.96      0.96      0.96       100
#                               infobox musical       0.95      0.96      0.96       100
#                        infobox musical artist       0.84      0.82      0.83       100
#                   infobox musical composition       0.98      0.96      0.97       100
#                         infobox nascar driver       0.90      0.96      0.93       100
#                    infobox nascar race report       0.98      1.00      0.99       100
#              infobox national basketball team       0.99      1.00      1.00       100
#                infobox national football team       0.95      0.95      0.95       100
# infobox ncaa basketball conference tournament       0.97      1.00      0.99       100
#             infobox ncaa football yearly game       0.98      0.96      0.97       100
#                             infobox newspaper       0.88      0.87      0.87       100
#                         infobox nfl biography       0.78      0.83      0.80       100
#                       infobox nfl team season       0.97      0.98      0.98       100
#                                 infobox noble       0.81      0.92      0.86       100
#                                  infobox nrhp       0.79      0.87      0.83       100
#                         infobox olympic event       0.94      0.94      0.94       100
#                                 infobox opera       0.95      0.99      0.97       100
#                          infobox organization       0.82      0.77      0.79       100
#                   infobox pageant titleholder       0.96      0.92      0.94       100
#              infobox pan american games event       0.95      0.94      0.94       100
#                      infobox paralympic event       0.97      0.98      0.98       100
#                                  infobox park       0.78      0.68      0.73       100
#                                infobox person       0.52      0.33      0.40       100
#                           infobox philosopher       0.85      0.79      0.82       100
#                                infobox planet       0.99      1.00      1.00       100
#                                  infobox play       0.98      0.93      0.95       100
#                       infobox political party       0.89      0.93      0.91       100
#                        infobox political post       0.96      0.86      0.91       100
#                            infobox politician       0.77      0.86      0.81       100
#                infobox portuguese subdivision       0.99      1.00      1.00       100
#                         infobox power station       0.94      0.96      0.95       100
#                                infobox prison       0.94      0.95      0.95       100
#                 infobox professional wrestler       1.00      0.98      0.99       100
#                        infobox protected area       0.89      0.80      0.84       100
#                        infobox protein family       0.88      0.92      0.90       100
#                             infobox publisher       0.97      0.86      0.91       100
#                             infobox racehorse       0.99      1.00      1.00       100
#                            infobox racing car       0.96      0.96      0.96       100
#                         infobox racing driver       0.93      0.86      0.90       100
#                            infobox radio show       0.90      0.94      0.92       100
#                         infobox radio station       0.98      0.98      0.98       100
#                                  infobox rail       0.85      0.88      0.87       100
#                             infobox rail line       0.85      0.83      0.84       100
#                          infobox rail service       0.98      0.93      0.95       100
#                          infobox record label       0.94      0.94      0.94       100
#                       infobox recurring event       0.83      0.84      0.84       100
#                   infobox religious biography       0.78      0.80      0.79       100
#                    infobox religious building       0.78      0.59      0.67       100
#                            infobox restaurant       0.95      0.95      0.95       100
#                                  infobox rfam       0.96      0.97      0.97       100
#                                 infobox river       1.00      0.94      0.97       100
#                                  infobox road       0.94      0.92      0.93       100
#                              infobox rockunit       0.97      0.98      0.98       100
#                  infobox romanian subdivision       0.95      1.00      0.98       100
#                               infobox royalty       0.88      0.82      0.85       100
#                       infobox rugby biography       0.92      0.98      0.95       100
#                infobox rugby league biography       0.99      0.96      0.97       100
#                            infobox rugby team       0.91      0.96      0.94       100
#                    infobox rugby union season       0.97      0.97      0.97       100
#                      infobox russian district       0.99      0.99      0.99       100
#            infobox russian inhabited locality       0.96      0.97      0.97       100
#               infobox sailboat specifications       0.98      0.98      0.98       100
#                                infobox sailor       0.98      0.97      0.97       100
#                                 infobox saint       0.90      0.84      0.87       100
#                                infobox school       0.99      0.91      0.95       100
#                       infobox school district       0.93      0.99      0.96       100
#                             infobox scientist       0.71      0.66      0.68       100
#                           infobox scotus case       0.95      0.98      0.97       100
#                         infobox serial killer       0.89      0.92      0.91       100
#                            infobox settlement       0.91      0.85      0.88       100
#                         infobox settlement al       1.00      1.00      1.00       100
#                            infobox ship begin       0.95      0.98      0.97       100
#                         infobox shopping mall       0.96      0.95      0.95       100
#                           infobox short story       0.96      0.93      0.94       100
#                                 infobox skier       0.95      0.97      0.96       100
#                        infobox soap character       0.94      0.95      0.95       100
#                              infobox software       0.90      0.93      0.92       100
#                                  infobox song       0.93      0.97      0.95       100
#            infobox song contest national year       0.99      1.00      1.00       100
#                           infobox spaceflight       0.98      1.00      0.99       100
#                          infobox speed skater       0.97      0.95      0.96       100
#                        infobox speedway rider       0.98      0.99      0.99       100
#                  infobox sport governing body       0.96      0.85      0.90       100
#              infobox sports competition event       0.94      0.84      0.89       100
#                         infobox sports league       0.83      0.83      0.83       100
#                        infobox sports rivalry       0.96      0.93      0.94       100
#                         infobox sports season       0.82      0.70      0.76       100
#                           infobox sports team       0.93      0.83      0.88       100
#                          infobox sportsperson       0.95      0.84      0.89       100
#                                  infobox sssi       0.95      0.95      0.95       100
#                               infobox station       0.99      0.91      0.95       100
#                                infobox street       0.84      0.81      0.82       100
#                               infobox surname       0.83      0.85      0.84       100
#                               infobox swimmer       0.96      0.97      0.97       100
#                        infobox swimming event       0.99      0.97      0.98       100
#                            infobox swiss town       0.99      1.00      1.00       100
#                            infobox television       0.91      0.82      0.86       100
#                    infobox television channel       0.95      0.94      0.94       100
#                    infobox television episode       0.99      0.95      0.97       100
#                     infobox television season       0.93      0.94      0.94       100
#                    infobox television station       0.97      0.98      0.98       100
#                      infobox tennis biography       0.99      0.98      0.98       100
#                          infobox tennis event       0.99      0.97      0.98       100
#                     infobox tennis tournament       0.99      0.99      0.99       100
#                                 infobox train       0.97      0.93      0.95       100
#                          infobox turkey place       0.96      1.00      0.98       100
#                           infobox u.s. county       0.98      1.00      0.99       100
#                      infobox u.s. legislation       0.91      0.96      0.94       100
#                  infobox uk constituency main       0.98      1.00      0.99       100
#                        infobox uk legislation       0.98      0.97      0.97       100
#                              infobox uk place       0.92      0.97      0.95       100
#                         infobox un resolution       1.00      0.99      0.99       100
#                            infobox university       0.94      0.89      0.91       100
#                                 infobox venue       0.90      0.90      0.90       100
#                            infobox video game       0.95      0.99      0.97       100
#                  infobox volleyball biography       0.99      1.00      1.00       100
#                             infobox waterfall       0.95      0.93      0.94       100
#                                infobox weapon       0.95      0.95      0.95       100
#                         infobox weather event       0.98      0.99      0.99       100
#                               infobox website       0.71      0.80      0.75       100
#                       infobox wrestling event       0.98      1.00      0.99       100
#                                infobox writer       0.70      0.69      0.69       100
#                                   infobox zoo       0.94      0.96      0.95       100
#
#                                      accuracy                           0.92     29800
#                                     macro avg       0.92      0.92      0.92     29800
#                                  weighted avg       0.92      0.92      0.92     29800
#
# Total execution time: 3267.51 seconds
# Results saved to C:\Users\Mohammad Hijjawi\Desktop\Data Science Project Code\BERT - Introduction\Training\Large\SVM\prediction_results.csv
