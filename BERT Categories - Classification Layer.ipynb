# %%
## BERT Categories

import pandas as pd
from transformers import BertTokenizer, BertForSequenceClassification
import torch
from torch.utils.data import DataLoader, Dataset
from torch.optim import AdamW
from tqdm import tqdm
from sklearn.metrics import classification_report
import time

# Define a custom class
class CustomDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts.apply(str)  # Convert all entries to strings
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]

        inputs = self.tokenizer(
            text,
            truncation=True,
            padding='max_length',
            max_length=self.max_len,
            return_tensors='pt'
        )

        return {
            'input_ids': inputs['input_ids'].squeeze(),
            'attention_mask': inputs['attention_mask'].squeeze(),
            'labels': torch.tensor(label, dtype=torch.long)
        }


training_file_path = r"C:\Users\Mohammad Hijjawi\Desktop\Data Science Project Code\Datasets for Classification Layer\training_dataset.csv"
df_train = pd.read_csv(training_file_path)

# Map infobox types to numerical labels
label_mapping = {label: idx for idx, label in enumerate(df_train['infobox_type'].unique())}
df_train['label'] = df_train['infobox_type'].map(label_mapping)

# Initialize the BERT model and tokenizer for classification
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=len(label_mapping))

# Create datasets and data loaders
train_dataset = CustomDataset(df_train['categories_text'], df_train['label'], tokenizer, max_len=512)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)

# Define optimizer and loss function using PyTorch's AdamW
optimizer = AdamW(model.parameters(), lr=2e-5)

# Set the model to training mode
model.train()
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)

# Training loop
max_epochs = 10
target_accuracy = 0.95  # 95% target accuracy

# Start time for training
start_time_training = time.time()

for epoch in range(max_epochs):
    print(f"Epoch {epoch+1}/{max_epochs}")
    total_loss = 0
    correct_predictions = 0

    for batch in tqdm(train_loader, desc="Training"):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        optimizer.zero_grad()

        outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        logits = outputs.logits

        total_loss += loss.item()
        loss.backward()
        optimizer.step()

        _, preds = torch.max(logits, dim=1)
        correct_predictions += torch.sum(preds == labels)

    avg_loss = total_loss / len(train_loader)
    accuracy = correct_predictions.double() / len(train_loader.dataset)

    print(f"Training loss: {avg_loss:.4f}, accuracy: {accuracy:.4f}")

    # Check if the target accuracy has been reached
    if accuracy >= target_accuracy:
        print(f"Target accuracy of {target_accuracy * 100}% reached. Stopping training.")
        break


end_time_training = time.time()

###total time
print(f"Total training time: {end_time_training - start_time_training:.2f} seconds")

# Save the trained model (optional)
torch.save(model.state_dict(), 'trained_model.pth')

# Set the model to evaluation mode
model.eval()


test_data_path = r"C:\Users\Mohammad Hijjawi\Desktop\Data Science Project Code\Datasets for Classification Layer\testing_data_set_for_Classification_Layer.csv"
test_data = pd.read_csv(test_data_path)

# chunks
chunk_size = 100
total_chunks = len(test_data) // chunk_size + (1 if len(test_data) % chunk_size != 0 else 0)

results_df_list = []
start_time = time.time()

for i in tqdm(range(total_chunks), desc="Processing test data"):
    start_idx = i * chunk_size
    end_idx = min((i + 1) * chunk_size, len(test_data))

 
    chunk_df = test_data.iloc[start_idx:end_idx]
    X_test_texts = chunk_df['categories_text'].apply(str).tolist()
    y_test = chunk_df['infobox_type'].tolist()
    titles_test = chunk_df['title'].tolist()

 
    inputs = tokenizer(X_test_texts, truncation=True, padding='max_length', max_length=512, return_tensors='pt')

   
    input_ids = inputs['input_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)

    # Predict the test data chunk
    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        y_pred = torch.argmax(logits, dim=1).cpu().numpy()

    # Create a DataFrame with the chunk results
    chunk_results_df = pd.DataFrame({
        'Title': titles_test,
        'Predicted Label': y_pred,
        'True Label': y_test
    })
    results_df_list.append(chunk_results_df)

# Concatenate 
results_df = pd.concat(results_df_list, ignore_index=True)

# Convert numeric predictions back to their original string labels
reverse_label_mapping = {v: k for k, v in label_mapping.items()}
results_df['Predicted Label'] = results_df['Predicted Label'].map(reverse_label_mapping)

misclassified = results_df[results_df['Predicted Label'] != results_df['True Label']]
misclass_counts = misclassified['True Label'].value_counts()
print("Top 5 Most Misclassified Labels:")
print(misclass_counts.head(5))

print(classification_report(results_df['True Label'], results_df['Predicted Label'], target_names=list(label_mapping.keys())))

results_csv_path = r"C:\Users\Mohammad Hijjawi\Desktop\Data Science Project Code\BERT - Categories\Classification Layer\prediction_results.csv"

#  CSV
results_df.to_csv(results_csv_path, index=False)
print(f"Results saved to {results_csv_path}")
print(f"Total execution time: {time.time() - start_time:.2f} seconds")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/10
# Training: 100%|██████████████████████████████████████████████████████████████████| 1863/1863 [3:01:53<00:00,  5.86s/it]
# Training loss: 3.9978, accuracy: 0.5123
# Epoch 2/10
# Training: 100%|██████████████████████████████████████████████████████████████████| 1863/1863 [3:04:26<00:00,  5.94s/it]
# Training loss: 1.5484, accuracy: 0.8648
# Epoch 3/10
# Training: 100%|██████████████████████████████████████████████████████████████████| 1863/1863 [3:05:03<00:00,  5.96s/it]
# Training loss: 0.6181, accuracy: 0.9214
# Epoch 4/10
# Training: 100%|██████████████████████████████████████████████████████████████████| 1863/1863 [3:09:21<00:00,  6.10s/it]
# Training loss: 0.3260, accuracy: 0.9438
# Epoch 5/10
# Training: 100%|██████████████████████████████████████████████████████████████████| 1863/1863 [3:07:56<00:00,  6.05s/it]
# Training loss: 0.2180, accuracy: 0.9556
# Target accuracy of 95.0% reached. Stopping training.
# Total training time: 55721.16 seconds
# Processing test data: 100%|████████████████████████████████████████████████████████| 298/298 [2:30:09<00:00, 30.23s/it]
# Top 5 Most Misclassified Labels:
# True Label
# infobox language                    93
# infobox gridiron football person    90
# infobox person                      82
# infobox korean name                 72
# infobox event                       56
# Name: count, dtype: int64
#                                                precision    recall  f1-score   support
#
#                         infobox afl biography       0.54      0.59      0.56       100
#                        infobox aircraft begin       0.99      1.00      1.00       100
#                               infobox artwork       1.00      1.00      1.00       100
#               infobox athletics championships       0.98      0.97      0.97       100
#                      infobox australian place       1.00      0.98      0.99       100
#                                infobox bridge       0.98      0.93      0.95       100
#                           infobox bus transit       0.97      1.00      0.99       100
#                         infobox cfl biography       0.95      0.93      0.94       100
#             infobox canada electoral district       0.86      0.86      0.86       100
#                               infobox chinese       0.98      0.99      0.99       100
#                infobox christian denomination       0.97      0.99      0.98       100
#                      infobox christian leader       0.74      0.86      0.79       100
#                       infobox fivb tournament       0.99      0.98      0.98       100
#            infobox figure skating competition       0.87      0.94      0.90       100
#                        infobox french commune       0.93      0.94      0.94       100
#                    infobox french subdivision       0.98      0.97      0.97       100
#                              infobox gaa club       0.94      0.89      0.91       100
#    infobox gaelic athletic association player       0.96      0.53      0.68       100
#                       infobox german location       1.00      1.00      1.00       100
#                infobox grand prix race report       0.95      0.98      0.97       100
#                           infobox greek dimos       1.00      0.99      0.99       100
#                          infobox hindu temple       0.96      0.98      0.97       100
#                              infobox building       0.92      0.97      0.94       100
#                   infobox indian constituency       0.86      0.98      0.92       100
#    infobox international football competition       0.99      0.95      0.97       100
#                        infobox italian comune       1.00      1.00      1.00       100
#                           infobox korean name       0.90      0.90      0.90       100
#                          infobox lunar crater       0.77      0.80      0.78       100
#                             infobox mma event       0.84      0.81      0.82       100
#           infobox malaysia electoral district       0.92      0.95      0.94       100
#                         infobox military unit       0.91      0.62      0.74       100
#                 infobox minor league baseball       0.93      0.97      0.95       100
#                               infobox musical       0.56      0.44      0.49       100
#                         infobox nascar driver       0.96      0.98      0.97       100
#                    infobox nascar race report       0.99      0.99      0.99       100
# infobox ncaa basketball conference tournament       0.93      0.95      0.94       100
#             infobox ncaa football yearly game       0.63      0.52      0.57       100
#            infobox college sports team season       0.92      0.59      0.72       100
#                         infobox nfl biography       1.00      0.99      0.99       100
#                       infobox nfl team season       0.60      0.59      0.59       100
#                    infobox baseball biography       0.86      0.95      0.90       100
#                                  infobox nrhp       0.87      0.93      0.90       100
#                             infobox newspaper       0.67      0.88      0.76       100
#                            infobox politician       0.76      0.87      0.81       100
#                         infobox olympic event       0.74      0.90      0.81       100
#              infobox pan american games event       0.96      0.82      0.89       100
#                      infobox paralympic event       0.85      0.94      0.89       100
#                        infobox political post       0.96      1.00      0.98       100
#                infobox portuguese subdivision       0.91      0.87      0.89       100
#                        infobox protected area       0.98      0.83      0.90       100
#                  infobox romanian subdivision       0.91      0.96      0.93       100
#                      infobox russian district       0.96      0.89      0.92       100
#            infobox russian inhabited locality       0.65      0.74      0.69       100
#                           infobox scotus case       1.00      0.95      0.97       100
#                                  infobox sssi       1.00      0.88      0.94       100
#                              infobox software       0.78      0.80      0.79       100
#                        infobox speedway rider       1.00      0.96      0.98       100
#                            infobox swiss town       0.99      0.96      0.97       100
#                          infobox turkey place       0.95      1.00      0.98       100
#                           infobox u.s. county       0.99      0.98      0.98       100
#                      infobox u.s. legislation       0.98      0.97      0.97       100
#                  infobox uk constituency main       0.98      1.00      0.99       100
#                        infobox uk legislation       0.89      0.86      0.87       100
#                              infobox uk place       0.99      0.92      0.95       100
#                         infobox un resolution       1.00      1.00      1.00       100
#                       infobox wrestling event       0.98      0.99      0.99       100
#                              infobox academic       0.99      0.97      0.98       100
#                   infobox aircraft occurrence       0.97      1.00      0.99       100
#                               infobox airline       0.93      0.98      0.96       100
#                               infobox airport       1.00      0.92      0.96       100
#                                 infobox album       0.89      0.86      0.87       100
#                               infobox anatomy       0.88      0.89      0.89       100
#                          infobox ancient site       0.96      0.97      0.97       100
#                              infobox animanga       0.90      0.97      0.93       100
#                             infobox architect       1.00      1.00      1.00       100
#                                infobox artist       0.90      0.88      0.89       100
#                    infobox artist discography       0.91      0.92      0.92       100
#                          infobox sportsperson       0.94      0.98      0.96       100
#                            infobox automobile       0.96      0.90      0.93       100
#                                 infobox award       0.81      0.44      0.57       100
#                      infobox badminton player       0.99      0.98      0.98       100
#                  infobox baseball team season       0.98      1.00      0.99       100
#                  infobox basketball biography       0.99      1.00      1.00       100
#                       infobox basketball club       1.00      1.00      1.00       100
#              infobox basketball league season       0.97      0.97      0.97       100
#                        infobox beauty pageant       0.73      0.98      0.84       100
#                   infobox bilateral relations       0.96      0.93      0.94       100
#                         infobox body of water       0.97      0.99      0.98       100
#                                  infobox book       0.90      0.98      0.94       100
#                           infobox book series       0.38      0.99      0.55       100
#                                 infobox boxer       0.91      0.98      0.94       100
#                                 infobox brand       0.99      0.99      0.99       100
#                              infobox cemetery       0.97      1.00      0.99       100
#                             infobox character       0.92      0.77      0.84       100
#                          infobox chess player       0.82      0.89      0.86       100
#                                infobox church       0.92      0.91      0.91       100
#                        infobox civil conflict       0.77      0.88      0.82       100
#                       infobox civilian attack       0.77      0.86      0.82       100
#                         infobox college coach       0.89      0.68      0.77       100
#               infobox college football player       0.97      1.00      0.99       100
#                              infobox comedian       0.99      0.97      0.98       100
#                      infobox comic book title       0.97      0.99      0.98       100
#                      infobox comics character       0.99      1.00      1.00       100
#                        infobox comics creator       0.99      1.00      1.00       100
#                               infobox company       0.98      0.92      0.95       100
#                               infobox concert       0.89      0.85      0.87       100
#                          infobox constituency       0.99      0.97      0.98       100
#                               infobox country       0.83      0.86      0.84       100
#                      infobox country at games       1.00      0.95      0.97       100
#                            infobox court case       1.00      1.00      1.00       100
#                        infobox cricket ground       0.99      0.99      0.99       100
#                          infobox cricket team       0.99      0.99      0.99       100
#                          infobox cricket tour       0.83      0.75      0.79       100
#                             infobox cricketer       0.91      0.99      0.95       100
#                              infobox criminal       0.99      0.99      0.99       100
#                              infobox cultivar       0.99      0.98      0.98       100
#                                infobox curler       0.25      0.10      0.14       100
#                          infobox cycling race       0.99      1.00      1.00       100
#                   infobox cycling race report       0.99      1.00      1.00       100
#                               infobox cyclist       0.96      0.93      0.94       100
#                                   infobox dam       0.90      0.93      0.92       100
#                          infobox darts player       0.72      0.47      0.57       100
#                                 infobox deity       0.90      0.91      0.91       100
#                            infobox diagnostic       1.00      0.99      0.99       100
#                               infobox diocese       1.00      0.98      0.99       100
#                                  infobox drug       0.97      0.96      0.96       100
#                            infobox earthquake       0.97      0.93      0.95       100
#                             infobox economist       0.98      0.99      0.99       100
#                              infobox election       0.99      0.99      0.99       100
#                                infobox enzyme       1.00      0.98      0.99       100
#                          infobox ethnic group       0.96      1.00      0.98       100
#                                 infobox event       1.00      1.00      1.00       100
#                          infobox field hockey       0.99      0.98      0.98       100
#                   infobox field hockey player       0.95      0.89      0.92       100
#                         infobox figure skater       0.86      0.79      0.82       100
#                                  infobox film       0.83      0.96      0.89       100
#                           infobox film awards       0.98      0.92      0.95       100
#                                  infobox flag       0.98      0.95      0.96       100
#                                  infobox food       0.95      0.97      0.96       100
#                    infobox football biography       0.97      1.00      0.99       100
#                         infobox football club       0.68      0.28      0.40       100
#                  infobox football club season       0.74      0.73      0.74       100
#               infobox football country season       0.58      0.07      0.13       100
#                       infobox football league       0.52      0.98      0.68       100
#                infobox football league season       0.90      0.90      0.90       100
#                        infobox football match       0.93      0.84      0.88       100
#                   infobox football tournament       1.00      1.00      1.00       100
#            infobox football tournament season       0.91      0.93      0.92       100
#                    infobox former subdivision       0.98      0.83      0.90       100
#                                infobox galaxy       0.90      0.93      0.92       100
#                                  infobox game       0.98      0.97      0.97       100
#                                 infobox games       0.99      0.98      0.98       100
#                            infobox given name       1.00      0.98      0.99       100
#                               infobox glacier       0.87      0.95      0.91       100
#                           infobox golf season       0.99      1.00      1.00       100
#                       infobox golf tournament       0.97      0.90      0.93       100
#                                infobox golfer       0.92      0.94      0.93       100
#                     infobox government agency       0.81      0.83      0.82       100
#                    infobox government cabinet       0.94      0.98      0.96       100
#              infobox gridiron football person       0.90      0.95      0.93       100
#                               infobox gymnast       0.93      0.71      0.81       100
#                    infobox handball biography       0.86      0.80      0.83       100
#                          infobox hiking trail       0.95      0.91      0.93       100
#                         infobox historic site       1.00      0.96      0.98       100
#                               infobox holiday       0.99      0.99      0.99       100
#                            infobox horseraces       1.00      0.97      0.98       100
#               infobox horseracing personality       0.99      0.99      0.99       100
#                              infobox hospital       0.95      0.98      0.97       100
#                                 infobox hotel       0.83      0.91      0.87       100
#                  infobox hurling championship       0.87      0.89      0.88       100
#                     infobox ice hockey player       0.68      0.68      0.68       100
#                infobox ice hockey team season       0.97      0.92      0.94       100
#            infobox individual golf tournament       0.89      0.95      0.92       100
#         infobox individual snooker tournament       0.95      0.91      0.93       100
#                 infobox information appliance       0.84      0.89      0.86       100
#                               infobox islands       0.94      0.94      0.94       100
#                               infobox journal       0.96      0.96      0.96       100
#                                 infobox judge       0.84      0.83      0.83       100
#                                infobox judoka       0.97      0.99      0.98       100
#                              infobox landform       0.90      1.00      0.95       100
#                              infobox language       1.00      1.00      1.00       100
#                       infobox language family       0.99      0.99      0.99       100
#                infobox law enforcement agency       0.99      0.96      0.97       100
#                           infobox legislation       0.96      0.97      0.97       100
#                  infobox legislative district       0.98      1.00      0.99       100
#                  infobox legislative election       0.98      0.92      0.95       100
#                           infobox legislature       0.53      0.93      0.68       100
#                               infobox library       0.99      0.95      0.97       100
#                            infobox lighthouse       0.83      0.73      0.78       100
#                            infobox locomotive       0.82      0.83      0.83       100
#                              infobox magazine       0.99      0.95      0.97       100
#                        infobox martial artist       0.98      1.00      0.99       100
#                     infobox medical condition       0.72      0.83      0.77       100
#                        infobox medical person       0.93      0.91      0.92       100
#                        infobox military award       0.95      1.00      0.98       100
#                     infobox military conflict       0.99      1.00      1.00       100
#                    infobox military structure       0.68      0.80      0.73       100
#                       infobox military person       0.26      0.18      0.21       100
#                                  infobox mine       0.85      0.78      0.81       100
#                               infobox mineral       0.99      0.99      0.99       100
#                          infobox mobile phone       0.96      0.94      0.95       100
#                                 infobox model       0.99      0.94      0.96       100
#                               infobox royalty       0.90      0.88      0.89       100
#                             infobox monastery       0.74      0.87      0.80       100
#                              infobox monument       0.99      0.96      0.97       100
#                      infobox motorcycle rider       1.00      0.96      0.98       100
#                              infobox mountain       0.96      0.97      0.97       100
#                         infobox mountain pass       0.96      1.00      0.98       100
#              infobox sports competition event       0.92      0.67      0.77       100
#                                infobox museum       0.97      0.83      0.89       100
#                       infobox recurring event       0.94      0.92      0.93       100
#                           infobox music genre       1.00      1.00      1.00       100
#                        infobox musical artist       0.92      0.93      0.93       100
#                   infobox musical composition       0.94      0.85      0.89       100
#              infobox national basketball team       0.98      0.97      0.97       100
#                infobox national football team       0.98      1.00      0.99       100
#                                 infobox noble       0.91      0.88      0.89       100
#                                 infobox opera       0.85      0.89      0.87       100
#                          infobox organization       0.97      0.92      0.94       100
#                   infobox pageant titleholder       0.99      0.97      0.98       100
#                                  infobox park       0.88      0.81      0.84       100
#                                infobox person       0.79      0.69      0.74       100
#                           infobox philosopher       0.86      0.59      0.70       100
#                                infobox planet       0.94      0.99      0.97       100
#                                  infobox play       0.99      0.98      0.98       100
#                       infobox political party       0.97      0.98      0.98       100
#                         infobox power station       0.90      0.94      0.92       100
#                                infobox prison       0.99      0.94      0.96       100
#                 infobox professional wrestler       1.00      1.00      1.00       100
#                        infobox protein family       0.75      0.82      0.78       100
#                             infobox publisher       0.96      0.95      0.95       100
#                             infobox racehorse       0.97      0.99      0.98       100
#                            infobox racing car       0.99      0.97      0.98       100
#                         infobox racing driver       0.97      0.97      0.97       100
#                            infobox radio show       0.99      0.98      0.98       100
#                         infobox radio station       0.92      0.97      0.95       100
#                                  infobox rail       1.00      0.99      0.99       100
#                             infobox rail line       1.00      0.98      0.99       100
#                          infobox rail service       0.86      0.88      0.87       100
#                          infobox record label       0.95      0.94      0.94       100
#                   infobox religious biography       0.98      0.98      0.98       100
#                    infobox religious building       0.70      0.68      0.69       100
#                            infobox restaurant       1.00      0.99      0.99       100
#                                  infobox rfam       0.91      0.96      0.93       100
#                                 infobox river       0.81      0.75      0.78       100
#                                  infobox road       0.93      1.00      0.96       100
#                              infobox rockunit       0.98      1.00      0.99       100
#                       infobox rugby biography       0.91      0.98      0.94       100
#                infobox rugby league biography       0.94      0.94      0.94       100
#                            infobox rugby team       0.86      0.99      0.92       100
#                    infobox rugby union season       0.79      0.99      0.88       100
#               infobox sailboat specifications       0.85      0.93      0.89       100
#                                infobox sailor       0.98      0.98      0.98       100
#                                 infobox saint       0.98      1.00      0.99       100
#                                infobox school       0.97      0.99      0.98       100
#                       infobox school district       1.00      0.93      0.96       100
#                             infobox scientist       1.00      1.00      1.00       100
#                         infobox serial killer       0.93      0.90      0.91       100
#                            infobox settlement       0.72      0.93      0.81       100
#                         infobox settlement al       0.83      0.82      0.82       100
#                            infobox ship begin       0.99      0.96      0.97       100
#                         infobox shopping mall       0.77      0.68      0.72       100
#                           infobox short story       0.95      0.81      0.88       100
#                                 infobox skier       0.95      0.76      0.84       100
#                        infobox soap character       0.92      0.99      0.95       100
#                                  infobox song       0.92      0.98      0.95       100
#            infobox song contest national year       0.83      0.88      0.85       100
#                           infobox spaceflight       0.84      0.92      0.88       100
#                          infobox speed skater       0.94      0.99      0.97       100
#                  infobox sport governing body       1.00      0.80      0.89       100
#                         infobox sports league       0.92      0.93      0.93       100
#                        infobox sports rivalry       0.92      0.96      0.94       100
#                         infobox sports season       0.93      0.91      0.92       100
#                           infobox sports team       0.99      0.96      0.97       100
#                                 infobox venue       0.99      0.91      0.95       100
#                               infobox station       0.91      0.96      0.94       100
#                                infobox street       0.96      0.98      0.97       100
#                               infobox surname       0.98      0.95      0.96       100
#                               infobox swimmer       1.00      0.97      0.98       100
#                        infobox swimming event       0.98      0.95      0.96       100
#                            infobox television       0.92      0.98      0.95       100
#                    infobox television channel       0.99      1.00      1.00       100
#                    infobox television episode       0.92      0.98      0.95       100
#                     infobox television season       0.99      1.00      1.00       100
#                    infobox television station       0.88      0.98      0.93       100
#                      infobox tennis biography       0.89      0.97      0.93       100
#                          infobox tennis event       1.00      1.00      1.00       100
#                     infobox tennis tournament       0.87      0.94      0.90       100
#                                 infobox train       0.91      0.92      0.92       100
#                            infobox university       0.97      0.99      0.98       100
#                            infobox video game       0.99      1.00      1.00       100
#                  infobox volleyball biography       0.98      0.98      0.98       100
#                             infobox waterfall       0.97      1.00      0.99       100
#                                infobox weapon       1.00      0.98      0.99       100
#                         infobox weather event       0.75      0.82      0.78       100
#                               infobox website       0.99      1.00      1.00       100
#                                infobox writer       0.74      0.83      0.78       100
#                                   infobox zoo       0.95      0.90      0.92       100
#
#                                      accuracy                           0.91     29800
#                                     macro avg       0.91      0.91      0.91     29800
#                                  weighted avg       0.91      0.91      0.91     29800
#
# Results saved to C:\Users\Mohammad Hijjawi\Desktop\Data Science Project Code\BERT - Categories\Classification Layer\prediction_results.csv
# Total execution time: 9010.78 seconds
